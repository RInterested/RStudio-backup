# %% [markdown]
# After [this tweet](https://twitter.com/blair_fix/status/1658254935769886721?s=20).

# %%
install.packages('moments')
# Out:
# Installing package into ‘/home/toni/R/x86_64-pc-linux-gnu-library/4.1’
# (as ‘lib’ is unspecified)

# %%
d = read.csv("inequality_and_murders.csv")
head(d)
colnames(d) = c("country", "inequality", "murders")
plot(log(murders) ~ inequality, d, pch = 19)
mod = lm(log(murders) ~ inequality, d)

summary(mod)
# Out:
#   Country Top.1..Share.of.Income Murder.Rate..per.100k.
# 1 AE      0.1531                 0.4637825
# 2 AF      0.1508                 6.6555612
# 3 AL      0.0924                 2.2894924
# 4 AM      0.1500                 1.6939156
# 5 AO      0.2598                 4.8470752
# 6 AR      0.1514                 5.3244787
# Call:
# lm(formula = log(murders) ~ inequality, data = d)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.7826 -0.6663 -0.1771  0.7028  3.2095
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  -0.8716     0.3209  -2.716  0.00738 **
# inequality   11.8049     1.9237   6.137 7.17e-09 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.144 on 150 degrees of freedom
# Multiple R-squared:  0.2007,	Adjusted R-squared:  0.1953
# F-statistic: 37.66 on 1 and 150 DF,  p-value: 7.169e-09
# plot without title

# %%
par(mfrow=c(4,2), mai = c(0.4, 0.7, 0.3, 0.11))

plot(murders ~ inequality, log="y", d, pch = 19, cex=0)
text(d$murders ~ d$inequality, labels=d$country, cex=0.8,
     col=ifelse(d$country %in% c('QA', 'BH','MZ'),2,1))

hist(residuals(mod), border=F)

plot(mod, 1:3, pch=19, cex.lab=1, cex.main=0.1, 
     cex=0.1, labels.id=d$country)

plot(mod, 4:6, pch=19, cex.lab=1, cex.main=0.1, 
     cex=ifelse(d$country %in% c('QA', 'BH','MZ'), 2, 0.1), 
     labels.id=d$country, 
     col=ifelse(d$country %in% c('QA', 'BH','MZ'),2,1))
# Out:
# Plot with title “”

# %%
# WITHOUT LOG TRANSFORM:

plot(murders ~ inequality, d, pch = 19)
mod2 = lm(murders ~ inequality, d)

summary(mod2)
# Out:
# Call:
# lm(formula = murders ~ inequality, data = d)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -12.508  -4.770  -2.631   0.012  47.065
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   -3.717      2.700  -1.377 0.170656
# inequality    63.436     16.187   3.919 0.000135 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.623 on 150 degrees of freedom
# Multiple R-squared:  0.09287,	Adjusted R-squared:  0.08683
# F-statistic: 15.36 on 1 and 150 DF,  p-value: 0.0001348
# plot without title

# %%
par(mfrow=c(4,2), mai = c(0.4, 0.7, 0.3, 0.11))

plot(murders ~ inequality, d, pch = 19, cex=0)
text(d$murders ~ d$inequality, labels=d$country, cex=0.8,
     col=ifelse(d$country %in% c('QA', 'BH','MZ'),2,1))

hist(residuals(mod2), border=F)

plot(mod2, 1:3, pch=19, cex.lab=1, cex.main=0.1, 
     cex=0.1, labels.id=d$country)

plot(mod2, 4:6, pch=19, cex.lab=1, cex.main=0.1, 
     cex=ifelse(d$country %in% c('QA', 'BH','MZ'), 2, 0.1), 
     labels.id=d$country, 
     col=ifelse(d$country %in% c('QA', 'BH','MZ'),2,1))
# Out:
# Plot with title “”

# %%
library(moments)
skewness(residuals(mod2))
# Out:
# [1] 2.667521
