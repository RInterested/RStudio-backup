# %%
lm(mpg ~ wt, mtcars)
# Out:
# Call:
# lm(formula = mpg ~ wt, data = mtcars)
#
# Coefficients:
# (Intercept)           wt
#      37.285       -5.344

# %%
plot(mpg ~ wt, mtcars, pch=19)
# Out:
# plot without title
